# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.1 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 27.5 MB/s  0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/DBDA52/Desktop/Statistics/260250125006_Anmol_Gangwar_BDA/Assignment7/students.csv")

# %%
df.head(5)
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
# ...

# %%
print(df.columns)
# Out:
# Index(['student_id', 'age', 'gender', 'academic_level', 'study_hours',
#        'self_study_hours', 'online_classes_hours', 'social_media_hours',
#        'gaming_hours', 'sleep_hours', 'screen_time_hours', 'exercise_minutes',
#        'caffeine_intake_mg', 'part_time_job', 'upcoming_deadline',
#        'internet_quality', 'mental_health_score', 'focus_index',
#        'burnout_level', 'productivity_score', 'exam_score'],
#       dtype='str')

# %%
df.shape
# Out:
# (5000, 21)

# %%
# Simple random sampling

# %%
df.isnull().sum()
# Out:
# student_id              0
# age                     0
# gender                  0
# academic_level          0
# study_hours             0
# self_study_hours        0
# online_classes_hours    0
# social_media_hours      0
# gaming_hours            0
# sleep_hours             0
# screen_time_hours       0
# exercise_minutes        0
# caffeine_intake_mg      0
# part_time_job           0
# upcoming_deadline       0
# internet_quality        0
# mental_health_score     0
# focus_index             0
# burnout_level           0
# productivity_score      0
# exam_score              0
# dtype: int64

# %%
sample_random = df.sample(n=10)
print(sample_random)
# Out:
#       student_id  age  gender academic_level  study_hours  self_study_hours  \
# 1345        1346   20  Female   Postgraduate         2.22              2.37
# 2342        2343   21   Other  Undergraduate         4.17              2.19
# 3924        3925   17    Male   Postgraduate         4.66              1.77
# 3007        3008   25    Male   Postgraduate         7.19              2.62
# 676          677   18   Other    High School         7.97              2.13
# 2594        2595   16  Female    High School         6.92              0.83
# 4583        4584   22  Female  Undergraduate         1.60              4.00
# 2128        2129   23  Female    High School         5.33              2.61
# 1154        1155   20   Other    High School         6.42              0.26
# 961          962   17   Other  Undergraduate         5.73              2.36
#
#       online_classes_hours  social_media_hours  gaming_hours  sleep_hours  \
# ...

# %%
systematic_sample = df.iloc[::5]
print(systematic_sample)
# Out:
#       student_id  age  gender academic_level  study_hours  self_study_hours  \
# 0              1   18   Other    High School         7.64              1.56
# 5              6   25    Male  Undergraduate         2.21              3.50
# 10            11   25   Other   Postgraduate         2.28              2.69
# 15            16   20   Other  Undergraduate         3.85              3.09
# 20            21   23    Male  Undergraduate         9.31              4.04
# ...          ...  ...     ...            ...          ...               ...
# 4975        4976   21    Male  Undergraduate         2.09              2.27
# 4980        4981   25    Male   Postgraduate         2.86              2.17
# 4985        4986   18  Female    High School         5.22              3.89
# 4990        4991   22    Male  Undergraduate         5.54              3.07
# 4995        4996   20   Other  Undergraduate         3.93              1.42
#
# ...

# %%
from sklearn.model_selection import train_test_split

sample_data, remaining = train_test_split(
    df,
    test_size = 0.8,
    stratify = df['gender'],
    random_state = 1
)
print(sample_data['gender'].value_counts())
# Out:
# gender
# Male      344
# Other     330
# Female    326
# Name: count, dtype: int64

# %%
cluster_sample = df[df['internet_quality'] == 'Good']
print(cluster_sample).head(10)
# Out:
#       student_id  age  gender academic_level  study_hours  self_study_hours  \
# 0              1   18   Other    High School         7.64              1.56
# 1              2   18   Other    High School         2.21              2.22
# 2              3   22    Male    High School         3.45              0.00
# 4              5   19   Other    High School         6.83              1.72
# 7              8   17    Male    High School         8.77              3.78
# ...          ...  ...     ...            ...          ...               ...
# 4994        4995   21  Female    High School         2.48              3.65
# 4995        4996   20   Other  Undergraduate         3.93              1.42
# 4997        4998   22    Male  Undergraduate         5.63              2.52
# 4998        4999   17    Male  Undergraduate         3.58              2.83
# 4999        5000   22   Other  Undergraduate         5.60              4.14
#
# ...
